# %% [markdown]
# #Prompt Parsing (No Hardcoded Keywords)
# ##Dynamic Pattern Recognition:
#
# Uses regex patterns to extract job titles, experience levels, locations
# Intelligently parses salary ranges, employment types, benefits
# Extracts industry context and company size preferences
# Calculates confidence scores based on parsed information
#
# ##Real Data via Google Places API
# Actual Business Discovery:
#
# Searches real businesses that might have job opportunities
# Gets detailed information (phone, website, ratings, hours)
# Finds staffing agencies, companies, and potential employers
# No mock data - everything is live from Google's database

# %%
import re
import json
import requests
from dataclasses import dataclass
from typing import List, Optional, Dict, Any
from datetime import datetime
import os

@dataclass
class JobOpportunity:
    business_name: str
    address: str
    phone: str
    rating: float
    business_type: str
    place_id: str
    website: Optional[str] = None
    hours: Optional[Dict] = None
    reviews_count: int = 0

@dataclass
class ParsedJobQuery:
    job_keywords: List[str]
    location_keywords: List[str]
    experience_indicators: List[str]
    employment_type_indicators: List[str]
    salary_mentioned: Optional[str]
    industry_keywords: List[str]
    company_size_indicators: List[str]
    benefits_mentioned: List[str]
    original_query: str
    confidence_score: float

class SmartJobPromptParser:
    def __init__(self, google_api_key: str):
        self.google_api_key = ''  #add API Key

        self.places_base_url = "https://maps.googleapis.com/maps/api/place"

        # Dynamic keyword extraction patterns - no hardcoded lists!
        self.job_patterns = [
            r'\b(\w+)\s+(engineer|developer|analyst|manager|specialist|coordinator|assistant|director|lead|intern)\b',
            r'\b(junior|senior|lead|principal|staff|associate)\s+(\w+)\b',
            r'\b(\w+)\s+(job|position|role|work|career)\b',
            r'\b(looking for|seeking|want|need)\s+(\w+(?:\s+\w+)*)\s+(position|job|role)\b'
        ]

        self.location_patterns = [
            r'\bin\s+([A-Za-z\s,]+)(?:\s|$)',
            r'\b(near|around|at|located)\s+([A-Za-z\s,]+)(?:\s|$)',
            r'\b([A-Za-z\s]+),?\s+(CA|California|Los Angeles|LA)\b'
        ]

        self.salary_patterns = [
            r'\$\s*(\d+(?:,\d{3})*(?:k|K)?)\s*(?:-|to)\s*\$?\s*(\d+(?:,\d{3})*(?:k|K)?)',
            r'\$\s*(\d+(?:,\d{3})*(?:k|K)?)\s*(?:per|/)\s*(hour|hr|year|annually)',
            r'(\d+(?:,\d{3})*(?:k|K)?)\s*(?:dollar|usd|\$)'
        ]

    def parse_query(self, query: str) -> ParsedJobQuery:
        """
        Intelligently parse job search query using NLP patterns
        No hardcoded keywords - extracts meaning from context
        """
        query_lower = query.lower().strip()

        # Extract job-related keywords dynamically
        job_keywords = self._extract_job_keywords(query_lower)

        # Extract location information
        location_keywords = self._extract_location_keywords(query_lower)

        # Extract experience indicators
        experience_indicators = self._extract_experience_indicators(query_lower)

        # Extract employment type indicators
        employment_type_indicators = self._extract_employment_type(query_lower)

        # Extract salary mentions
        salary_mentioned = self._extract_salary_info(query_lower)

        # Extract industry context
        industry_keywords = self._extract_industry_context(query_lower)

        # Extract company size indicators
        company_size_indicators = self._extract_company_size(query_lower)

        # Extract benefits mentioned
        benefits_mentioned = self._extract_benefits(query_lower)

        # Calculate confidence score based on extracted information
        confidence_score = self._calculate_confidence(
            job_keywords, location_keywords, experience_indicators
        )

        return ParsedJobQuery(
            job_keywords=job_keywords,
            location_keywords=location_keywords,
            experience_indicators=experience_indicators,
            employment_type_indicators=employment_type_indicators,
            salary_mentioned=salary_mentioned,
            industry_keywords=industry_keywords,
            company_size_indicators=company_size_indicators,
            benefits_mentioned=benefits_mentioned,
            original_query=query,
            confidence_score=confidence_score
        )

    def _extract_job_keywords(self, query: str) -> List[str]:
        """Extract job-related terms using pattern matching"""
        keywords = []

        # Common job title patterns
        for pattern in self.job_patterns:
            matches = re.findall(pattern, query, re.IGNORECASE)
            for match in matches:
                if isinstance(match, tuple):
                    keywords.extend([word.strip() for word in match if word.strip()])
                else:
                    keywords.append(match.strip())

        # Extract individual meaningful words that could be job-related
        words = re.findall(r'\b[a-zA-Z]{3,}\b', query)
        potential_job_words = [
            word for word in words
            if len(word) > 3 and word not in ['looking', 'seeking', 'want', 'need', 'jobs', 'work']
        ]
        keywords.extend(potential_job_words[:5])  # Limit to prevent noise

        return list(set(keywords))  # Remove duplicates

    def _extract_location_keywords(self, query: str) -> List[str]:
        """Extract location information"""
        locations = []

        for pattern in self.location_patterns:
            matches = re.findall(pattern, query, re.IGNORECASE)
            for match in matches:
                if isinstance(match, tuple):
                    locations.extend([loc.strip() for loc in match if loc.strip()])
                else:
                    locations.append(match.strip())

        # Default to LA if no location specified
        if not locations:
            locations = ["Los Angeles, CA"]

        return locations

    def _extract_experience_indicators(self, query: str) -> List[str]:
        """Extract experience level indicators"""
        experience_patterns = [
            r'\b(entry.level|junior|senior|lead|principal|staff|director|manager|intern|graduate|experienced|beginner)\b',
            r'\b(\d+)\s*(year|yr)s?\s*(experience|exp)\b',
            r'\b(new grad|recent graduate|fresh|starter)\b'
        ]

        indicators = []
        for pattern in experience_patterns:
            matches = re.findall(pattern, query, re.IGNORECASE)
            for match in matches:
                if isinstance(match, tuple):
                    indicators.extend([ind.strip() for ind in match if ind.strip()])
                else:
                    indicators.append(match.strip())

        return indicators

    def _extract_employment_type(self, query: str) -> List[str]:
        """Extract employment type indicators"""
        type_pattern = r'\b(full.time|part.time|contract|freelance|remote|hybrid|on.site|temporary|permanent|internship)\b'
        matches = re.findall(type_pattern, query, re.IGNORECASE)
        return [match.replace('.', '-') for match in matches]

    def _extract_salary_info(self, query: str) -> Optional[str]:
        """Extract salary information"""
        for pattern in self.salary_patterns:
            match = re.search(pattern, query, re.IGNORECASE)
            if match:
                return match.group(0)
        return None

    def _extract_industry_context(self, query: str) -> List[str]:
        """Extract industry-related keywords"""
        industry_patterns = [
            r'\b(tech|technology|healthcare|finance|education|retail|manufacturing|startup|enterprise)\b',
            r'\b(ai|artificial intelligence|machine learning|blockchain|cloud|mobile|web)\b',
            r'\b(hospital|clinic|school|university|bank|restaurant|store)\b'
        ]

        keywords = []
        for pattern in industry_patterns:
            matches = re.findall(pattern, query, re.IGNORECASE)
            keywords.extend(matches)

        return keywords

    def _extract_company_size(self, query: str) -> List[str]:
        """Extract company size indicators"""
        size_pattern = r'\b(startup|small|large|enterprise|corporation|big tech|fortune|unicorn)\b'
        matches = re.findall(size_pattern, query, re.IGNORECASE)
        return matches

    def _extract_benefits(self, query: str) -> List[str]:
        """Extract mentioned benefits"""
        benefits_pattern = r'\b(health insurance|401k|remote|flexible|vacation|pto|stock options|equity|bonus)\b'
        matches = re.findall(benefits_pattern, query, re.IGNORECASE)
        return matches

    def _calculate_confidence(self, job_keywords: List[str], location_keywords: List[str],
                            experience_indicators: List[str]) -> float:
        """Calculate confidence score for parsed query"""
        score = 0.0

        if job_keywords:
            score += 0.4 * min(len(job_keywords) / 3, 1.0)

        if location_keywords:
            score += 0.3

        if experience_indicators:
            score += 0.2

        score += 0.1  # Base score

        return round(min(score, 1.0), 2)

    def search_businesses_for_jobs(self, parsed_query: ParsedJobQuery) -> List[JobOpportunity]:
        """
        Use Google Places API to find businesses that might have job opportunities
        """
        all_opportunities = []

        # Build search queries based on parsed information
        search_queries = self._build_search_queries(parsed_query)

        for search_query in search_queries:
            try:
                opportunities = self._search_places(search_query, parsed_query.location_keywords[0])
                all_opportunities.extend(opportunities)
            except Exception as e:
                print(f"Error searching for '{search_query}': {e}")
                continue

        # Remove duplicates and rank by relevance
        unique_opportunities = self._deduplicate_and_rank(all_opportunities, parsed_query)

        return unique_opportunities[:20]  # Return top 20 opportunities

    def _build_search_queries(self, parsed_query: ParsedJobQuery) -> List[str]:
        """Build Google Places search queries based on parsed information"""
        queries = []

        # Combine job keywords with industry context
        for job_keyword in parsed_query.job_keywords[:3]:  # Top 3 job keywords
            # Direct job search
            queries.append(f"{job_keyword} jobs")

            # Industry-specific searches
            for industry in parsed_query.industry_keywords:
                queries.append(f"{industry} {job_keyword}")

            # Company type searches
            for company_type in parsed_query.company_size_indicators:
                queries.append(f"{company_type} {job_keyword}")

        # Fallback searches if no specific job keywords
        if not parsed_query.job_keywords:
            queries.extend([
                "employment agency",
                "staffing agency",
                "recruiting",
                "human resources",
                "career center"
            ])

        return queries[:5]  # Limit API calls

    def _search_places(self, query: str, location: str) -> List[JobOpportunity]:
        """Search Google Places API"""
        url = f"{self.places_base_url}/textsearch/json"

        params = {
            'query': f"{query} in {location}",
            'key': self.google_api_key,
            'type': 'establishment'
        }

        response = requests.get(url, params=params)

        if response.status_code != 200:
            raise Exception(f"API Error: {response.status_code}")

        data = response.json()

        if data['status'] != 'OK':
            if data['status'] == 'ZERO_RESULTS':
                return []
            raise Exception(f"Places API Error: {data['status']}")

        opportunities = []

        for place in data.get('results', []):
            # Get additional details
            details = self._get_place_details(place['place_id'])

            opportunity = JobOpportunity(
                business_name=place.get('name', 'Unknown'),
                address=place.get('formatted_address', 'Address not available'),
                phone=details.get('phone', 'Phone not available'),
                rating=place.get('rating', 0.0),
                business_type=', '.join(place.get('types', [])),
                place_id=place['place_id'],
                website=details.get('website'),
                hours=details.get('hours'),
                reviews_count=place.get('user_ratings_total', 0)
            )

            opportunities.append(opportunity)

        return opportunities

    def _get_place_details(self, place_id: str) -> Dict[str, Any]:
        """Get detailed information about a place"""
        url = f"{self.places_base_url}/details/json"

        params = {
            'place_id': place_id,
            'fields': 'website,formatted_phone_number,opening_hours',
            'key': self.google_api_key
        }

        try:
            response = requests.get(url, params=params)
            if response.status_code == 200:
                data = response.json()
                if data['status'] == 'OK':
                    result = data.get('result', {})
                    return {
                        'website': result.get('website'),
                        'phone': result.get('formatted_phone_number'),
                        'hours': result.get('opening_hours', {}).get('weekday_text')
                    }
        except Exception as e:
            print(f"Error getting place details: {e}")

        return {}

    def _deduplicate_and_rank(self, opportunities: List[JobOpportunity],
                             parsed_query: ParsedJobQuery) -> List[JobOpportunity]:
        """Remove duplicates and rank by relevance"""
        # Remove duplicates based on place_id
        seen_ids = set()
        unique_opportunities = []

        for opp in opportunities:
            if opp.place_id not in seen_ids:
                seen_ids.add(opp.place_id)
                unique_opportunities.append(opp)

        # Rank by relevance (rating, reviews count, keyword matching)
        def relevance_score(opp: JobOpportunity) -> float:
            score = 0.0

            # Rating weight
            score += opp.rating * 0.3

            # Reviews count weight (logarithmic scale)
            if opp.reviews_count > 0:
                score += min(0.3, 0.1 * (opp.reviews_count / 100))

            # Keyword matching in business name
            business_name_lower = opp.business_name.lower()
            for keyword in parsed_query.job_keywords:
                if keyword.lower() in business_name_lower:
                    score += 0.2

            # Industry matching
            for industry in parsed_query.industry_keywords:
                if industry.lower() in business_name_lower or industry.lower() in opp.business_type.lower():
                    score += 0.2

            return score

        unique_opportunities.sort(key=relevance_score, reverse=True)
        return unique_opportunities

    def format_results(self, opportunities: List[JobOpportunity],
                      parsed_query: ParsedJobQuery) -> str:
        """Format search results"""
        if not opportunities:
            return f"No job opportunities found for: '{parsed_query.original_query}'"

        result = f"\n🔍 Job Opportunities Search Results\n"
        result += f"Query: '{parsed_query.original_query}'\n"
        result += f"Confidence Score: {parsed_query.confidence_score}/1.0\n"
        result += "=" * 60 + "\n\n"

        result += "📊 Parsed Query Analysis:\n"
        result += f"  • Job Keywords: {', '.join(parsed_query.job_keywords) or 'None detected'}\n"
        result += f"  • Location: {', '.join(parsed_query.location_keywords)}\n"
        result += f"  • Experience Level: {', '.join(parsed_query.experience_indicators) or 'Any level'}\n"
        result += f"  • Employment Type: {', '.join(parsed_query.employment_type_indicators) or 'Not specified'}\n"
        result += f"  • Salary Mentioned: {parsed_query.salary_mentioned or 'Not specified'}\n"
        result += f"  • Industry: {', '.join(parsed_query.industry_keywords) or 'General'}\n"
        result += f"  • Company Size: {', '.join(parsed_query.company_size_indicators) or 'Any size'}\n\n"

        result += f"Found {len(opportunities)} potential job opportunities:\n"
        result += "=" * 60 + "\n"

        for i, opp in enumerate(opportunities, 1):
            result += f"{i}. {opp.business_name}\n"
            result += f"   📍 Address: {opp.address}\n"
            result += f"   📞 Phone: {opp.phone}\n"
            result += f"   ⭐ Rating: {opp.rating}/5.0 ({opp.reviews_count} reviews)\n"
            result += f"   🏢 Type: {opp.business_type}\n"
            if opp.website:
                result += f"   🌐 Website: {opp.website}\n"
            result += f"   💡 Tip: Contact them directly to inquire about job openings\n"
            result += "-" * 60 + "\n"

        return result

def main():
    """Demo function"""
    print("🔍 Smart Job Search with Google Places API")
    print("=" * 50)

    # You need to set your Google API key
    api_key = os.getenv('GOOGLE_PLACES_API_KEY')

    if not api_key:
        print("❌ Error: Please set GOOGLE_PLACES_API_KEY environment variable")
        print("Get your API key from: https://developers.google.com/maps/documentation/places/web-service/get-api-key")
        return

    parser = SmartJobPromptParser(api_key)

    # Test queries
    test_queries = [
        "senior software engineer jobs in Santa Monica",
        "data scientist positions at tech startups",
        "marketing manager role with health insurance benefits",
        "entry level developer remote work",
        "healthcare jobs near downtown LA"
    ]

    for query in test_queries:
        print(f"\n🔍 Searching: '{query}'")

        # Parse query
        parsed = parser.parse_query(query)

        # Search for opportunities
        opportunities = parser.search_businesses_for_jobs(parsed)

        # Display results
        print(parser.format_results(opportunities, parsed))
        print("\n" + "=" * 80 + "\n")

if __name__ == "__main__":
    # Interactive mode
    api_key = os.getenv('GOOGLE_PLACES_API_KEY')

    if not api_key:
        print("❌ Please set GOOGLE_PLACES_API_KEY environment variable")
        print("Example: export GOOGLE_PLACES_API_KEY='your_api_key_here'")
        print("Get API key: https://developers.google.com/maps/documentation/places/web-service/get-api-key")
        exit(1)

    parser = SmartJobPromptParser(api_key)

    print("🚀 Smart Job Search Parser with Google Places API")
    print("Enter natural language job search queries")
    print("Examples:")
    print("  • 'senior software engineer jobs in Santa Monica'")
    print("  • 'data scientist positions at AI companies'")
    print("  • 'marketing manager with remote work options'")
    print("Type 'quit' to exit\n")

    while True:
        query = input("🔍 Enter job search: ").strip()

        if query.lower() in ['quit', 'exit', 'q']:
            print("👋 Thanks for using the smart job search parser!")
            break

        if not query:
            continue

        try:
            # Parse and search
            parsed = parser.parse_query(query)
            opportunities = parser.search_businesses_for_jobs(parsed)

            # Display results
            print(parser.format_results(opportunities, parsed))
            print()

        except Exception as e:
            print(f"❌ Error: {e}")
            print("Please try a different search query.\n")
# Out:
# ❌ Please set GOOGLE_PLACES_API_KEY environment variable
# Example: export GOOGLE_PLACES_API_KEY='your_api_key_here'
# Get API key: https://developers.google.com/maps/documentation/places/web-service/get-api-key
# 🚀 Smart Job Search Parser with Google Places API
# Enter natural language job search queries
# Examples:
#   • 'senior software engineer jobs in Santa Monica'
#   • 'data scientist positions at AI companies'
#   • 'marketing manager with remote work options'
# Type 'quit' to exit
#
#
# 🔍 Job Opportunities Search Results
# Query: 'pet grooming'
# Confidence Score: 0.53/1.0
# ============================================================
#
# 📊 Parsed Query Analysis:
#   • Job Keywords: grooming
#   • Location: Los Angeles, CA
#   • Experience Level: Any level
#   • Employment Type: Not specified
#   • Salary Mentioned: Not specified
#   • Industry: General
#   • Company Size: Any size
#
# Found 19 potential job opportunities:
# ============================================================
# 1. Sunset Mobile Grooming
#    📍 Address: 6678 Delco Ave, Winnetka, CA 91306, United States
#    📞 Phone: (818) 299-6076
#    ⭐ Rating: 5/5.0 (139 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://sunsetmobilegrooming.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 2. 21Pooch Dog & Cat grooming salon
#    📍 Address: 1061 S Broadway, Los Angeles, CA 90015, United States
#    📞 Phone: (213) 589-8304
#    ⭐ Rating: 4.8/5.0 (134 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://www.21pooch.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 3. Blue Pooch Dog Grooming
#    📍 Address: 11737 W Pico Blvd, Los Angeles, CA 90064, United States
#    📞 Phone: (310) 473-4173
#    ⭐ Rating: 4.7/5.0 (161 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.bluepooch.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 4. Calis Pet Grooming
#    📍 Address: 7708 S Broadway, Los Angeles, CA 90003, United States
#    📞 Phone: (323) 677-1518
#    ⭐ Rating: 4.9/5.0 (81 reviews)
#    🏢 Type: point_of_interest, establishment
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 5. Lovely Nose Pet Grooming
#    📍 Address: 4209 W Washington Blvd, Los Angeles, CA 90016, United States
#    📞 Phone: (323) 402-0440
#    ⭐ Rating: 4.9/5.0 (80 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://lovelynosegrooming.top/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 6. MFD Grooming & Wellness
#    📍 Address: 741 N Stanley Ave, Los Angeles, CA 90046, United States
#    📞 Phone: (323) 952-6466
#    ⭐ Rating: 5/5.0 (40 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://www.mfdgroomingandwellness.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 7. Groom - Dog Care With Love
#    📍 Address: 8749 Holloway Dr, West Hollywood, CA 90069, United States
#    📞 Phone: (310) 492-5222
#    ⭐ Rating: 5/5.0 (234 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://groomla.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 8. Petco Grooming
#    📍 Address: 200 S La Brea Ave ste c, Los Angeles, CA 90036, United States
#    📞 Phone: (323) 934-8444
#    ⭐ Rating: 4.8/5.0 (90 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://stores.petco.com/ca/losangeles/full-service-grooming-losangeles-ca-908.html
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 9. Breezy Paw Mobile Grooming
#    📍 Address: 8084 Calvin Ave, Northridge, CA 91324, United States
#    📞 Phone: (818) 984-7424
#    ⭐ Rating: 4.8/5.0 (84 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://breezypawgrooming.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 10. Moon Shine Grooming & Pet Wash
#    📍 Address: 4473 Santa Monica Blvd, Los Angeles, CA 90029, United States
#    📞 Phone: (323) 664-4600
#    ⭐ Rating: 4.6/5.0 (115 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://www.theurbanpet.net/self-wash-pods-and-full-service-grooming-at-moonshine-grooming/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 11. 21Pooch Hollywood
#    📍 Address: 5137 W Sunset Blvd Unit 213, 2nd floor, Los Angeles, CA 90027, United States
#    📞 Phone: (310) 290-3905
#    ⭐ Rating: 4.8/5.0 (223 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://www.21pooch.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 12. Avenue of the Paws: Luxury Mobile Dog Grooming
#    📍 Address: 4419 Van Nuys Blvd, Sherman Oaks, CA 91423, United States
#    📞 Phone: (818) 510-0922
#    ⭐ Rating: 4.6/5.0 (39 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://booking.moego.pet/go/form?formId=9748c327329b4d13a815572709c48b19
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 13. More Than A Bath Grooming. (Groomer)
#    📍 Address: 11200 Long Beach Blvd #42, Lynwood, CA 90262, United States
#    📞 Phone: (562) 618-8926
#    ⭐ Rating: 4.6/5.0 (37 reviews)
#    🏢 Type: point_of_interest, establishment
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 14. Fur Town Pet Grooming
#    📍 Address: 7574 Melrose Ave, Los Angeles, CA 90046, United States
#    📞 Phone: (800) 823-1305
#    ⭐ Rating: 4.6/5.0 (30 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://furtownpetspa.com/melrose-ca/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 15. Dirty Paws
#    📍 Address: 4501 E Carson St Suite 102, Long Beach, CA 90808, United States
#    📞 Phone: (562) 420-2277
#    ⭐ Rating: 4.8/5.0 (132 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://www.dirtypawslb.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 16. Los Angeles Pet Grooming
#    📍 Address: 6022 Santa Fe Ave, Huntington Park, CA 90255, United States
#    📞 Phone: (323) 818-6741
#    ⭐ Rating: 4.2/5.0 (103 reviews)
#    🏢 Type: store, point_of_interest, establishment
#    🌐 Website: https://www.instagram.com/losangelespetgrooming/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 17. Bowie Barker West Hollywood
#    📍 Address: 7609 Beverly Blvd, Los Angeles, CA 90036, United States
#    📞 Phone: (323) 372-0622
#    ⭐ Rating: 4.8/5.0 (107 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.bowiebarker.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 18. Collar & Comb
#    📍 Address: 7813 W Sunset Blvd, Los Angeles, CA 90046, United States
#    📞 Phone: (323) 688-2275
#    ⭐ Rating: 4.2/5.0 (216 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://collarandcomb.dog/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 19. Collar & Comb | Hancock Park
#    📍 Address: 343 N La Brea Ave, Los Angeles, CA 90036, United States
#    📞 Phone: (323) 688-2275
#    ⭐ Rating: 4.3/5.0 (112 reviews)
#    🏢 Type: park, point_of_interest, establishment
#    🌐 Website: https://collarandcomb.dog/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
#
#
#
# 🔍 Job Opportunities Search Results
# Query: 'chef job'
# Confidence Score: 0.67/1.0
# ============================================================
#
# 📊 Parsed Query Analysis:
#   • Job Keywords: chef, job
#   • Location: Los Angeles, CA
#   • Experience Level: Any level
#   • Employment Type: Not specified
#   • Salary Mentioned: Not specified
#   • Industry: General
#   • Company Size: Any size
#
# Found 20 potential job opportunities:
# ============================================================
# 1. Rockstar Staffing
#    📍 Address: 5901 W Century Blvd #750, Los Angeles, CA 90045, United States
#    📞 Phone: (949) 910-8834
#    ⭐ Rating: 4.9/5.0 (472 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.rockstarstaffing.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 2. Motion Recruitment
#    📍 Address: 10990 Wilshire Blvd Suite 300, Los Angeles, CA 90024, United States
#    📞 Phone: (310) 996-0200
#    ⭐ Rating: 4.9/5.0 (445 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://motionrecruitment.com/about/locations/los-angeles-it-staffing-recruiting?utm_source=google-business&utm_medium=organic&utm_campaign=los-angeles
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 3. Haute Chefs Los Angeles
#    📍 Address: 13131 Sherman Way #103, North Hollywood, CA 91605, United States
#    📞 Phone: (818) 358-4391
#    ⭐ Rating: 5/5.0 (19 reviews)
#    🏢 Type: food, point_of_interest, establishment
#    🌐 Website: https://hautechefsla.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 4. Private Chefs Inc.
#    📍 Address: 11355 W Olympic Blvd, Los Angeles, CA 90064, United States
#    📞 Phone: (310) 278-4707
#    ⭐ Rating: 5/5.0 (10 reviews)
#    🏢 Type: food, point_of_interest, establishment
#    🌐 Website: https://privatechefsinc.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 5. Private Chefs Club
#    📍 Address: 1819 Holmby Ave APT 104, Los Angeles, CA 90025, United States
#    📞 Phone: (310) 773-6343
#    ⭐ Rating: 5/5.0 (2 reviews)
#    🏢 Type: point_of_interest, establishment
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 6. Private Chefs Guild
#    📍 Address: 7250 Franklin Ave, Los Angeles, CA 90046, United States
#    📞 Phone: (310) 955-8043
#    ⭐ Rating: 5/5.0 (2 reviews)
#    🏢 Type: food, point_of_interest, establishment
#    🌐 Website: https://www.mychefnate.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 7. Private Chefs Inc
#    📍 Address: 269 S Beverly Dr # 244, Beverly Hills, CA 90212, United States
#    📞 Phone: (310) 278-4707
#    ⭐ Rating: 4.9/5.0 (31 reviews)
#    🏢 Type: food, point_of_interest, establishment
#    🌐 Website: http://privatechefsinc.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 8. Los Angeles Jobs Inc
#    📍 Address: 566 W 6th St, Los Angeles, CA 90017, United States
#    📞 Phone: (323) 419-3263
#    ⭐ Rating: 5/5.0 (1 reviews)
#    🏢 Type: point_of_interest, establishment
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 9. Sweet Greek Personal Chef Services
#    📍 Address: Holly Drive and, Primrose Ave, Los Angeles, CA 90068, United States
#    📞 Phone: (323) 999-1722
#    ⭐ Rating: 4.6/5.0 (14 reviews)
#    🏢 Type: restaurant, food, point_of_interest, establishment
#    🌐 Website: http://mysweetgreek.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 10. DILIGENT STAFFING INC
#    📍 Address: 2820 S Vermont Ave STE 21, Los Angeles, CA 90007, United States
#    📞 Phone: (323) 332-0400
#    ⭐ Rating: 4.7/5.0 (154 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.diligentstaffinginc.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 11. Reliable Staffing
#    📍 Address: 11111 Santa Monica Blvd #1700, Los Angeles, CA 90025, United States
#    📞 Phone: (310) 575-9675
#    ⭐ Rating: 4.6/5.0 (167 reviews)
#    🏢 Type: finance, health, point_of_interest, establishment
#    🌐 Website: https://reliablestaffing.com/los-angeles-california/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 12. PVJOBS
#    📍 Address: 4112 Main St, Los Angeles, CA 90037, United States
#    📞 Phone: (323) 432-3955
#    ⭐ Rating: 4.3/5.0 (34 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://www.pvjobs.org/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 13. Downtown Community Job Center
#    📍 Address: 121 E Pico Blvd, Los Angeles, CA 90015, United States
#    📞 Phone: (213) 747-2064
#    ⭐ Rating: 4.3/5.0 (15 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://idepsca.org/daylabor
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 14. Brad Metzger Restaurant Solutions
#    📍 Address: 11705 W Pico Blvd, Los Angeles, CA 90064, United States
#    📞 Phone: (310) 245-5108
#    ⭐ Rating: 5/5.0 (2 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.restaurant-solutions.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 15. Hospitality Training Academy Kitchen
#    📍 Address: 1234 S Western Ave, Los Angeles, CA 90006, United States
#    📞 Phone: (213) 866-8541
#    ⭐ Rating: 4.8/5.0 (50 reviews)
#    🏢 Type: food, point_of_interest, establishment
#    🌐 Website: http://www.lahta.org/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 16. GoLive! Staffing
#    📍 Address: 6404 Wilshire Blvd #500, Los Angeles, CA 90048, United States
#    📞 Phone: (323) 965-7582
#    ⭐ Rating: 4.4/5.0 (166 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://culinarystaffing.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 17. Ultimate Staffing Services
#    📍 Address: 1925 Century Park E #1700, Los Angeles, CA 90067, United States
#    📞 Phone: (310) 201-0062
#    ⭐ Rating: 4.7/5.0 (76 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://www.ultimatestaffing.com/locations/view/century-city/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 18. East Los Angeles America's Job Center
#    📍 Address: 5301 Whittier Blvd, Los Angeles, CA 90022, United States
#    📞 Phone: (323) 887-7122
#    ⭐ Rating: 4.2/5.0 (15 reviews)
#    🏢 Type: local_government_office, point_of_interest, establishment
#    🌐 Website: http://www.ca.gov/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 19. Career Group
#    📍 Address: 10100 CA-2 suite 900, Los Angeles, CA 90067, United States
#    📞 Phone: (310) 277-8188
#    ⭐ Rating: 4.4/5.0 (122 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://careergroupcompanies.com/career-group/?utm_source=google&utm_medium=organic&utm_campaign=gmb_website
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 20. L.A. Jobs Employment Agency
#    📍 Address: 16530 Ventura Blvd BoulevardSte 500, Encino, CA 91436, United States
#    📞 Phone: (818) 500-0048
#    ⭐ Rating: 4/5.0 (6 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.lajobsea.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
#
#
#
# 🔍 Job Opportunities Search Results
# Query: 'hair styling jobs please'
# Confidence Score: 0.8/1.0
# ============================================================
#
# 📊 Parsed Query Analysis:
#   • Job Keywords: styling, please, hair
#   • Location: Los Angeles, CA
#   • Experience Level: Any level
#   • Employment Type: Not specified
#   • Salary Mentioned: Not specified
#   • Industry: General
#   • Company Size: Any size
#
# Found 20 potential job opportunities:
# ============================================================
# 1. KSY Kim Sun Young Hair & Beauty Salon LA
#    📍 Address: 306 N Western Ave, Los Angeles, CA 90004, United States
#    📞 Phone: (323) 462-4247
#    ⭐ Rating: 4.9/5.0 (896 reviews)
#    🏢 Type: hair_care, beauty_salon, point_of_interest, establishment
#    🌐 Website: http://www.kimsunyoung.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 2. HAIR BY MINA COLORIST TEAM
#    📍 Address: Inside Of Raffine, 3580 Wilshire Blvd, Los Angeles, CA 90010, United States
#    📞 Phone: (213) 321-2298
#    ⭐ Rating: 4.9/5.0 (386 reviews)
#    🏢 Type: hair_care, point_of_interest, establishment
#    🌐 Website: https://www.hairbymina.com/contact/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 3. Theodora Hair Studio Vermont
#    📍 Address: 440 S Vermont Ave #107, Los Angeles, CA 90020, United States
#    📞 Phone: (213) 380-0008
#    ⭐ Rating: 4.8/5.0 (318 reviews)
#    🏢 Type: hair_care, health, point_of_interest, establishment
#    🌐 Website: http://www.theodorahairstudio.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 4. Hair Arca
#    📍 Address: 3660 Wilshire Blvd Suite 101, Los Angeles, CA 90010, United States
#    📞 Phone: (213) 380-0247
#    ⭐ Rating: 4.8/5.0 (518 reviews)
#    🏢 Type: hair_care, point_of_interest, establishment
#    🌐 Website: http://www.arcagenolus.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 5. Hairroin Salon
#    📍 Address: 4637 Hollywood Blvd, Los Angeles, CA 90027, United States
#    📞 Phone: (323) 333-9458
#    ⭐ Rating: 4.7/5.0 (406 reviews)
#    🏢 Type: hair_care, point_of_interest, establishment
#    🌐 Website: http://www.hairroinsalon.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 6. HAIR Los Angeles
#    📍 Address: 1427 East 4th St UNIT 3, Los Angeles, CA 90033, United States
#    📞 Phone: (310) 388-1979
#    ⭐ Rating: 4.9/5.0 (221 reviews)
#    🏢 Type: art_gallery, hair_care, point_of_interest, establishment
#    🌐 Website: http://hairlosangeles.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 7. GLOSS & GLAM Hair Salon & Head Spa
#    📍 Address: 8474 W 3rd St # 204, Los Angeles, CA 90048, United States
#    📞 Phone: (323) 424-4224
#    ⭐ Rating: 4.9/5.0 (166 reviews)
#    🏢 Type: spa, hair_care, beauty_salon, point_of_interest, health, establishment
#    🌐 Website: https://www.glossglamhairspa.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 8. Hair People Full Services Salon
#    📍 Address: 1123 Vine St # 8, Los Angeles, CA 90038, United States
#    📞 Phone: (323) 463-2127
#    ⭐ Rating: 4.9/5.0 (109 reviews)
#    🏢 Type: hair_care, beauty_salon, point_of_interest, establishment
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 9. Hair Boss Salon
#    📍 Address: 727 N La Brea Ave, Los Angeles, CA 90038, United States
#    📞 Phone: (323) 272-3779
#    ⭐ Rating: 5/5.0 (77 reviews)
#    🏢 Type: hair_care, point_of_interest, establishment
#    🌐 Website: http://www.hairbossextensions.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 10. Works of Art Hair Salon
#    📍 Address: 4655 Hollywood Blvd, Los Angeles, CA 90027, United States
#    📞 Phone: (323) 667-0072
#    ⭐ Rating: 4.9/5.0 (104 reviews)
#    🏢 Type: hair_care, beauty_salon, point_of_interest, establishment
#    🌐 Website: https://worksofarthairsalon.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 11. THE ONE BEAUTY HAIR SALON
#    📍 Address: 1149 S Beverly Dr, Los Angeles, CA 90035, United States
#    📞 Phone: (310) 567-3792
#    ⭐ Rating: 4.9/5.0 (103 reviews)
#    🏢 Type: hair_care, beauty_salon, point_of_interest, establishment
#    🌐 Website: http://www.theonebeautysalon.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 12. Motion Recruitment
#    📍 Address: 10990 Wilshire Blvd Suite 300, Los Angeles, CA 90024, United States
#    📞 Phone: (310) 996-0200
#    ⭐ Rating: 4.9/5.0 (445 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: https://motionrecruitment.com/about/locations/los-angeles-it-staffing-recruiting?utm_source=google-business&utm_medium=organic&utm_campaign=los-angeles
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 13. Atelier by Tiffany
#    📍 Address: 400 S Western Ave #201, Los Angeles, CA 90020, United States
#    📞 Phone: (213) 380-3235
#    ⭐ Rating: 4.9/5.0 (2019 reviews)
#    🏢 Type: hair_care, point_of_interest, establishment
#    🌐 Website: http://atelierbytiffany.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 14. Johnny & Mia Hair Studio
#    📍 Address: 3948 Wilshire Blvd, Los Angeles, CA 90010, United States
#    📞 Phone: (213) 568-3505
#    ⭐ Rating: 4.9/5.0 (95 reviews)
#    🏢 Type: beauty_salon, hair_care, point_of_interest, establishment
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 15. Hairicc
#    📍 Address: 4052 Del Rey Ave Suite 106, Marina Del Rey, CA 90292, United States
#    📞 Phone: (424) 401-2347
#    ⭐ Rating: 4.9/5.0 (77 reviews)
#    🏢 Type: hair_care, beauty_salon, point_of_interest, establishment
#    🌐 Website: https://hairicc.com/los-angeles/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 16. MiKADO Personal Styling
#    📍 Address: 1249 S Grand Ave Suite 504, Los Angeles, CA 90015, United States
#    📞 Phone: (800) 982-1628
#    ⭐ Rating: 5/5.0 (43 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.mikadopersonalstyling.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 17. Salon Biology
#    📍 Address: 1731 Westwood Blvd, Los Angeles, CA 90024, United States
#    📞 Phone: (424) 465-9014
#    ⭐ Rating: 4.9/5.0 (241 reviews)
#    🏢 Type: hair_care, beauty_salon, finance, point_of_interest, establishment
#    🌐 Website: http://www.salonbiology.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 18. Hair Salon Nanana Parena
#    📍 Address: 11301 W Olympic Blvd, Los Angeles, CA 90064, United States
#    📞 Phone: (310) 575-3998
#    ⭐ Rating: 4.5/5.0 (159 reviews)
#    🏢 Type: beauty_salon, hair_care, point_of_interest, establishment
#    🌐 Website: http://www.nananaparena.com/english_los.html
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 19. Hair by Julianne
#    📍 Address: 2970 W Olympic Blvd #103, Los Angeles, CA 90006, United States
#    📞 Phone: (213) 210-4698
#    ⭐ Rating: 4.6/5.0 (125 reviews)
#    🏢 Type: hair_care, point_of_interest, establishment
#    🌐 Website: http://hairbyjulianne.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 20. Salon New Look Studio
#    📍 Address: 4004 S Vermont Ave Suite #1 #2, Los Angeles, CA 90037, United States
#    📞 Phone: (323) 386-3021
#    ⭐ Rating: 4.8/5.0 (200 reviews)
#    🏢 Type: beauty_salon, point_of_interest, establishment
#    🌐 Website: https://salon-new-look-studio-los-angeles.belliata.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
#
#
#
# 🔍 Job Opportunities Search Results
# Query: 'chef jobs'
# Confidence Score: 0.53/1.0
# ============================================================
#
# 📊 Parsed Query Analysis:
#   • Job Keywords: chef
#   • Location: Los Angeles, CA
#   • Experience Level: Any level
#   • Employment Type: Not specified
#   • Salary Mentioned: Not specified
#   • Industry: General
#   • Company Size: Any size
#
# Found 11 potential job opportunities:
# ============================================================
# 1. Haute Chefs Los Angeles
#    📍 Address: 13131 Sherman Way #103, North Hollywood, CA 91605, United States
#    📞 Phone: (818) 358-4391
#    ⭐ Rating: 5/5.0 (19 reviews)
#    🏢 Type: point_of_interest, food, establishment
#    🌐 Website: https://hautechefsla.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 2. Private Chefs Inc.
#    📍 Address: 11355 W Olympic Blvd, Los Angeles, CA 90064, United States
#    📞 Phone: (310) 278-4707
#    ⭐ Rating: 5/5.0 (10 reviews)
#    🏢 Type: point_of_interest, food, establishment
#    🌐 Website: https://privatechefsinc.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 3. Private Chefs Club
#    📍 Address: 1819 Holmby Ave APT 104, Los Angeles, CA 90025, United States
#    📞 Phone: (310) 773-6343
#    ⭐ Rating: 5/5.0 (2 reviews)
#    🏢 Type: point_of_interest, establishment
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 4. Private Chefs Guild
#    📍 Address: 7250 Franklin Ave, Los Angeles, CA 90046, United States
#    📞 Phone: (310) 955-8043
#    ⭐ Rating: 5/5.0 (2 reviews)
#    🏢 Type: point_of_interest, food, establishment
#    🌐 Website: https://www.mychefnate.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 5. Private Chefs Inc
#    📍 Address: 269 S Beverly Dr # 244, Beverly Hills, CA 90212, United States
#    📞 Phone: (310) 278-4707
#    ⭐ Rating: 4.9/5.0 (31 reviews)
#    🏢 Type: point_of_interest, food, establishment
#    🌐 Website: http://privatechefsinc.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 6. Sweet Greek Personal Chef Services
#    📍 Address: Holly Drive and, Primrose Ave, Los Angeles, CA 90068, United States
#    📞 Phone: (323) 999-1722
#    ⭐ Rating: 4.6/5.0 (14 reviews)
#    🏢 Type: restaurant, point_of_interest, food, establishment
#    🌐 Website: http://mysweetgreek.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 7. Brad Metzger Restaurant Solutions
#    📍 Address: 11705 W Pico Blvd, Los Angeles, CA 90064, United States
#    📞 Phone: (310) 245-5108
#    ⭐ Rating: 5/5.0 (2 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.restaurant-solutions.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 8. Hospitality Training Academy Kitchen
#    📍 Address: 1234 S Western Ave, Los Angeles, CA 90006, United States
#    📞 Phone: (213) 866-8541
#    ⭐ Rating: 4.8/5.0 (50 reviews)
#    🏢 Type: point_of_interest, food, establishment
#    🌐 Website: http://www.lahta.org/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 9. GoLive! Staffing
#    📍 Address: 6404 Wilshire Blvd #500, Los Angeles, CA 90048, United States
#    📞 Phone: (323) 965-7582
#    ⭐ Rating: 4.4/5.0 (166 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://culinarystaffing.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 10. Private Chef Network
#    📍 Address: 7350 Melrose Ave A, Los Angeles, CA 90046, United States
#    📞 Phone: (747) 222-4522
#    ⭐ Rating: 0.0/5.0 (0 reviews)
#    🏢 Type: point_of_interest, establishment
#    🌐 Website: http://www.eliteprivatechefs.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
# 11. Kitchen Culture Recruiting
#    📍 Address: 900 N Sycamore Ave, Los Angeles, CA 90038, United States
#    📞 Phone: None
#    ⭐ Rating: 0.0/5.0 (0 reviews)
#    🏢 Type: restaurant, point_of_interest, food, establishment
#    🌐 Website: http://www.culturerecruiting.com/
#    💡 Tip: Contact them directly to inquire about job openings
# ------------------------------------------------------------
